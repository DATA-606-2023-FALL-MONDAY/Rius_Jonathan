# %%
import matplotlib.pyplot as plt        #Import relevant libraries. Pandas for dataframes and ploty and matplotlib for visualization. Other libraries just in case.
import pandas as pd
import numpy as np
import plotly.graph_objects as go
plt.rcParams['figure.figsize'] = 25, 12 #Increase general size for matplot.lib

# %% [markdown]
# https://github.com/DATA-606-2023-FALL-MONDAY/UMBC-Data-Science-Capstone/blob/main/Assignment_04_Complete_EDA.md

# %% [markdown]
# ##**US Employment, Inflation and GDP Exploration and Economic Forecasting**##

# %% [markdown]
# ##The following is a study of macroeconmic data and using machine learning for economic forecasting. Hypothesis testing and correlations will be used for further exploration. Basically the project aims to explore macro economic data and make use of machine learning for forecasting.##

# %% [markdown]
# ## Machine Learning economic ideas
#
# https://www.projectpro.io/article/projects-on-machine-learning-applications-in-finance/510
#
# https://www.kansascityfed.org/Economic%20Review/documents/921/2018-Machine%20Learning%20Approaches%20to%20Macroeconomic%20Forecasting.pdf
#
# https://www.oecd.org/naec/new-economic-policymaking/Macroeconomic_forecasting_with_machine_learnin_NAEC_Woloszko.pdf

# %% [markdown]
# ##U.S Employment Rate

# %%
dataframe1 = pd.read_excel('/content/SeriesReport-Cleaned.xlsx',skiprows=11)

dataframe1
# Out:
#     Year  Jan  Feb  Mar   Apr   May   Jun   Jul  Aug  Sep  Oct  Nov  Dec
# 0   2013  8.0  7.7  7.5   7.6   7.5   7.5   7.3  7.2  7.2  7.2  6.9  6.7
# 1   2014  6.6  6.7  6.7   6.2   6.3   6.1   6.2  6.1  5.9  5.7  5.8  5.6
# 2   2015  5.7  5.5  5.4   5.4   5.6   5.3   5.2  5.1  5.0  5.0  5.1  5.0
# 3   2016  4.8  4.9  5.0   5.1   4.8   4.9   4.8  4.9  5.0  4.9  4.7  4.7
# 4   2017  4.7  4.6  4.4   4.4   4.4   4.3   4.3  4.4  4.3  4.2  4.2  4.1
# 5   2018  4.0  4.1  4.0   4.0   3.8   4.0   3.8  3.8  3.7  3.8  3.8  3.9
# 6   2019  4.0  3.8  3.8   3.6   3.7   3.6   3.7  3.7  3.5  3.6  3.6  3.6
# 7   2020  3.5  3.5  4.4  14.7  13.2  11.0  10.2  8.4  7.9  6.9  6.7  6.7
# 8   2021  6.3  6.2  6.1   6.1   5.8   5.9   5.4  5.2  4.8  4.5  4.2  3.9
# 9   2022  4.0  3.8  3.6   3.6   3.6   3.6   3.5  3.7  3.5  3.7  3.6  3.5
# 10  2023  3.4  3.6  3.5   3.4   3.7   3.6   3.5  3.8  NaN  NaN  NaN  NaN

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    11 non-null     int64
#  1   Jan     11 non-null     float64
#  2   Feb     11 non-null     float64
#  3   Mar     11 non-null     float64
#  4   Apr     11 non-null     float64
#  5   May     11 non-null     float64
#  6   Jun     11 non-null     float64
#  7   Jul     11 non-null     float64
#  8   Aug     11 non-null     float64
#  9   Sep     10 non-null     float64
#  10  Oct     10 non-null     float64
#  11  Nov     10 non-null     float64
#  12  Dec     10 non-null     float64
# dtypes: float64(12), int64(1)
# memory usage: 1.2 KB

# %%
dataframe1.describe()
# Out:
#               Year        Jan        Feb        Mar        Apr        May  \
# count    11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   2018.000000   5.000000   4.945455   4.945455   5.827273   5.672727
# std       3.316625   1.472413   1.410931   1.335937   3.224621   2.799675
# min    2013.000000   3.400000   3.500000   3.500000   3.400000   3.600000
# 25%    2015.500000   4.000000   3.800000   3.900000   3.800000   3.750000
# 50%    2018.000000   4.700000   4.600000   4.400000   5.100000   4.800000
# 75%    2020.500000   6.000000   5.850000   5.750000   6.150000   6.050000
# max    2023.000000   8.000000   7.700000   7.500000  14.700000  13.200000
#
#              Jun        Jul        Aug        Sep      Oct        Nov  \
# count  11.000000  11.000000  11.000000  10.000000  10.0000  10.000000
# mean    5.436364   5.263636   5.118182   5.080000   4.9500   4.860000
# std     2.228126   2.033850   1.553588   1.517161   1.2869   1.233063
# ...

# %%
dataframe1.info
# Out:
# <bound method DataFrame.info of     Year  Jan  Feb  Mar   Apr   May   Jun   Jul  Aug  Sep  Oct  Nov  Dec
# 0   2013  8.0  7.7  7.5   7.6   7.5   7.5   7.3  7.2  7.2  7.2  6.9  6.7
# 1   2014  6.6  6.7  6.7   6.2   6.3   6.1   6.2  6.1  5.9  5.7  5.8  5.6
# 2   2015  5.7  5.5  5.4   5.4   5.6   5.3   5.2  5.1  5.0  5.0  5.1  5.0
# 3   2016  4.8  4.9  5.0   5.1   4.8   4.9   4.8  4.9  5.0  4.9  4.7  4.7
# 4   2017  4.7  4.6  4.4   4.4   4.4   4.3   4.3  4.4  4.3  4.2  4.2  4.1
# 5   2018  4.0  4.1  4.0   4.0   3.8   4.0   3.8  3.8  3.7  3.8  3.8  3.9
# 6   2019  4.0  3.8  3.8   3.6   3.7   3.6   3.7  3.7  3.5  3.6  3.6  3.6
# 7   2020  3.5  3.5  4.4  14.7  13.2  11.0  10.2  8.4  7.9  6.9  6.7  6.7
# 8   2021  6.3  6.2  6.1   6.1   5.8   5.9   5.4  5.2  4.8  4.5  4.2  3.9
# 9   2022  4.0  3.8  3.6   3.6   3.6   3.6   3.5  3.7  3.5  3.7  3.6  3.5
# 10  2023  3.4  3.6  3.5   3.4   3.7   3.6   3.5  3.8  NaN  NaN  NaN  NaN>

# %%
dataframe1.isnull()
# Out:
#      Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False   True
#
#       Oct    Nov    Dec
# 0   False  False  False
# 1   False  False  False
# ...

# %%
DF3= dataframe1.interpolate(method ='linear', limit_direction ='forward')

DF3
# Out:
#     Year  Jan  Feb  Mar   Apr   May   Jun   Jul  Aug  Sep  Oct  Nov  Dec
# 0   2013  8.0  7.7  7.5   7.6   7.5   7.5   7.3  7.2  7.2  7.2  6.9  6.7
# 1   2014  6.6  6.7  6.7   6.2   6.3   6.1   6.2  6.1  5.9  5.7  5.8  5.6
# 2   2015  5.7  5.5  5.4   5.4   5.6   5.3   5.2  5.1  5.0  5.0  5.1  5.0
# 3   2016  4.8  4.9  5.0   5.1   4.8   4.9   4.8  4.9  5.0  4.9  4.7  4.7
# 4   2017  4.7  4.6  4.4   4.4   4.4   4.3   4.3  4.4  4.3  4.2  4.2  4.1
# 5   2018  4.0  4.1  4.0   4.0   3.8   4.0   3.8  3.8  3.7  3.8  3.8  3.9
# 6   2019  4.0  3.8  3.8   3.6   3.7   3.6   3.7  3.7  3.5  3.6  3.6  3.6
# 7   2020  3.5  3.5  4.4  14.7  13.2  11.0  10.2  8.4  7.9  6.9  6.7  6.7
# 8   2021  6.3  6.2  6.1   6.1   5.8   5.9   5.4  5.2  4.8  4.5  4.2  3.9
# 9   2022  4.0  3.8  3.6   3.6   3.6   3.6   3.5  3.7  3.5  3.7  3.6  3.5
# 10  2023  3.4  3.6  3.5   3.4   3.7   3.6   3.5  3.8  3.5  3.7  3.6  3.5

# %%
import plotly.express as px                                        # This is very similar to the bar graph interactive, however not is a line. Like before, font sizes are increased when needed.
fig = px.line(DF3, x="Year", y= ["Jan","Feb","Mar","Apr","May",'Jun',"Jul","Aug","Sep","Oct","Nov","Dec"])

fig.update_layout(
    autosize=False,
    width=1500,
    height=800,)

fig.update_layout(                                                  # Simply put this code is to change the font, title, and legend. Like before.
legend=go.layout.Legend(
x=0,
y=1,
traceorder="normal",
font=dict(
family="sans-serif",
size=20,
color="black"
)
)
)

fig.update_layout(title_text="U.S Unemployment Rate", title_x=0.5)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px


fig = px.scatter(

    DF3, x='Year', y=["Jan","Feb","Mar","Apr","May",'Jun',"Jul","Aug","Sep","Oct","Nov","Dec"], opacity=0.65,

    trendline='ols', trendline_color_override='darkblue'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##U.S Inflation Rate (as CPI)

# %%
Project_df = pd.read_csv("/content/CPIAUCSL.csv") # Read csv using this code, print df

Project_df
# Out:
#            DATE  CPIAUCSL
# 0    1947-01-01    21.480
# 1    1947-02-01    21.620
# 2    1947-03-01    22.000
# 3    1947-04-01    22.000
# 4    1947-05-01    21.950
# ..          ...       ...
# 915  2023-04-01   302.918
# 916  2023-05-01   303.294
# 917  2023-06-01   303.841
# 918  2023-07-01   304.348
# 919  2023-08-01   306.269
#
# [920 rows x 2 columns]

# %%
Project_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DATE      920 non-null    object
#  1   CPIAUCSL  920 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 14.5+ KB

# %%
Project_df.describe()
# Out:
#          CPIAUCSL
# count  920.000000
# mean   118.202466
# std     84.100387
# min     21.480000
# 25%     32.155000
# 50%    107.100000
# 75%    188.950000
# max    306.269000

# %%
Project_df.isnull().sum()
# Out:
# DATE        0
# CPIAUCSL    0
# dtype: int64

# %%
import plotly.express as px                                        # This is very similar to the bar graph interactive, however not is a line. Like before, font sizes are increased when needed.
fig = px.line(Project_df, x="DATE", y="CPIAUCSL")

fig.update_layout(
    autosize=False,
    width=1500,
    height=800,)

fig.update_layout(                                                  # Simply put this code is to change the font, title, and legend. Like before.
legend=go.layout.Legend(
x=0,
y=1,
traceorder="normal",
font=dict(
family="sans-serif",
size=20,
color="black"
)
)
)

fig.update_layout(title_text="U.S Inflation Rate", title_x=0.5)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px


fig = px.scatter(

    Project_df, x=Project_df.index, y="CPIAUCSL", opacity=0.65,

    trendline='ols', trendline_color_override='darkblue'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# U.S GDP

# %%
Project_df_1 = pd.read_csv("/content/GDP (1).csv") # Read csv using this code, print df

Project_df_1
# Out:
#            DATE        GDP
# 0    1947-01-01    243.164
# 1    1947-04-01    245.968
# 2    1947-07-01    249.585
# 3    1947-10-01    259.745
# 4    1948-01-01    265.742
# ..          ...        ...
# 301  2022-04-01  25248.476
# 302  2022-07-01  25723.941
# 303  2022-10-01  26137.992
# 304  2023-01-01  26529.774
# 305  2023-04-01  26798.605
#
# [306 rows x 2 columns]

# %%
Project_df_1.info
# Out:
# <bound method DataFrame.info of            DATE        GDP
# 0    1947-01-01    243.164
# 1    1947-04-01    245.968
# 2    1947-07-01    249.585
# 3    1947-10-01    259.745
# 4    1948-01-01    265.742
# ..          ...        ...
# 301  2022-04-01  25248.476
# 302  2022-07-01  25723.941
# 303  2022-10-01  26137.992
# 304  2023-01-01  26529.774
# 305  2023-04-01  26798.605
#
# [306 rows x 2 columns]>

# %%
Project_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    306 non-null    object
#  1   GDP     306 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.9+ KB

# %%
Project_df_1.describe()
# Out:
#                 GDP
# count    306.000000
# mean    7002.992261
# std     7180.200656
# min      243.164000
# 25%      798.045750
# 50%     4262.527500
# 75%    12065.473000
# max    26798.605000

# %%
Project_df_1['percent'] = (Project_df_1['GDP'] /
                  Project_df_1['GDP'].sum()) * 100

# %%
Project_df_1
# Out:
#            DATE        GDP   percent
# 0    1947-01-01    243.164  0.011347
# 1    1947-04-01    245.968  0.011478
# 2    1947-07-01    249.585  0.011647
# 3    1947-10-01    259.745  0.012121
# 4    1948-01-01    265.742  0.012401
# ..          ...        ...       ...
# 301  2022-04-01  25248.476  1.178230
# 302  2022-07-01  25723.941  1.200418
# 303  2022-10-01  26137.992  1.219740
# 304  2023-01-01  26529.774  1.238022
# 305  2023-04-01  26798.605  1.250567
#
# [306 rows x 3 columns]

# %%
Project_df_1.isnull().sum()
# Out:
# DATE       0
# GDP        0
# percent    0
# dtype: int64

# %%
import plotly.express as px                                        # This is very similar to the bar graph interactive, however not is a line. Like before, font sizes are increased when needed.
fig = px.line(Project_df_1, x="DATE", y="percent")

fig.update_layout(
    autosize=False,
    width=1500,
    height=800,)

fig.update_layout(                                                  # Simply put this code is to change the font, title, and legend. Like before.
legend=go.layout.Legend(
x=0,
y=1,
traceorder="normal",
font=dict(
family="sans-serif",
size=20,
color="black"
)
)
)

fig.update_layout(title_text="U.S GDP", title_x=0.5)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px


fig = px.scatter(

    Project_df_1, x=Project_df_1.index, y="percent", opacity=0.65,

    trendline='ols', trendline_color_override='darkblue'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Combined Data

# %% [markdown]
# ##Research Questions

# %% [markdown]
# What will inflation, GDP and unemployment rate look in the future?
#
# How can we use hypothesis testing to compare macroeconomic data against other countries?
#
# What are some correlations between data sets?

# %% [markdown]
# ## Things to consider moving forward

# %% [markdown]
# - Other applications of machine learning
# - Inclusion of international data
# - Viewing interesting correalations between macroeconmic data
# - Include more economic data
# - Comparion of diffferent countries

# %% [markdown]
# Complete Section 4 - EDA
#
#
# Include description on data cleansing and preparation: I used three different datasets, only one had null values. I used interpolate to fill out the null values on the first dataset. For regression I still need to convert the date sections into datetime to treat like the x axis.
#
#
# Include visualizations and interpretations: Most of the graphs are increasing besides the first one and the trendline shows. GDP and inflation naturally increases as a country develops but employment rate is different. It will go and down more drastically as the economy shrinks or increases.
